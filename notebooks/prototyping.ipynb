# %% [markdown]
# # Prototyping Notebook
#
# Use this notebook to work on your data analysis and visualization. You can then reference these results in your final report.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample data creation
data = pd.DataFrame({
    'A': np.random.randn(100),
    'B': np.random.randn(100)
})

data.head()
# Out:
#           A         B
# 0  0.720112 -1.162458
# 1 -0.880299  1.706077
# 2 -1.262227 -1.459792
# 3 -1.105211  0.668834
# 4 -0.192166  0.353499

# %%
#| label: fig-prototype-plot
#| fig-cap: "A plot generated in a prototyping notebook and embedded in the report."
plt.scatter(data['A'], data['B'])
plt.title("Prototyping Scatter Plot")
plt.show()
